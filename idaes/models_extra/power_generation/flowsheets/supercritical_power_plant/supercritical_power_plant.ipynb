# %% [markdown]
# # Supercritical Power Plant Flowsheet Example
#
#
# ## 1. Introduction
#
#
# This example is to demonstrate a supercritical pulverized coal power plant model. The power plant consists of two major sub-systems (or flowsheets), a boiler heat exchanger network and a steam cycle. This jupyter notebook provides the workflow to import the steam cycle flowsheet, import the boiler heat exchanger network, connect and run both the flowsheets, and display the main results.

# %% [markdown]
# ## 2. Model Description
#
# The case study demonstrated here is for a ~620MW gross power output. The process flow diagram is shown in section 3 of this jupyter notebook. Figure 1 shows the boiler heat exchanger network, while, figure 2 shows the steam cycle system.
#
# The streams connecting both the flowsheets are:
# &emsp; a) The main steam: that connects the boiler attemperator to the throttle valves of the high pressure turbine
# &emsp; b) The cold reheat: that connects the final stage of the high pressure turbine to the boiler reheater
# &emsp; c) The hot reheat: that connects the boiler reheater to the intermediate pressure turbine
# &emsp; d) The main feed water: that connects the last feed water heater to the boiler economizer
#
# To get a more detailed description of the power plant flowsheet, review the ```SCPC_full_plant.py``` file. For details in terms of specific power plant units (for example dimensions, parameters, and variables), more information can be found at ```supercritical_steam_cycle.py``` and ```boiler_subflowsheet.py```.

# %% [markdown]
# ## 3. Process Flow Diagram (PFD)

# %%
from IPython.display import SVG, display
display('Boiler subsystem PFD',
        SVG(filename='Boiler_scpc_PFD.svg'),
        'Steam Cycle subsystem PFD',
        SVG(filename='../supercritical_steam_cycle/supercritical_steam_cycle.svg'))
# Out:
# 'Boiler subsystem PFD'
# 'Steam Cycle subsystem PFD'

# %% [markdown]
# ## 4. Run power plant model example
#
# This example runs the main ``SCPC_full_plant.py`` script, which, imports two flowsheets (steam cycle and boiler heat exchanger network), builds arcs to connect both flowsheets, and run the full power plant model.

# %%
# import SCPC power plant
# initialize steam cycle, initialize boiler heat exchanger network, connect both flowsheets, 
# and run SCPC plant.
# %run SCPC_full_plant.py
# Out:
# 2020-09-04 15:08:02 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:02 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.condenser.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.condenser.area
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh1.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh1.condense.area
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.condense.area
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.desuperheat.area
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:06 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh2.cooling.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.condense.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.desuperheat.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh3.cooling.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.condense.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.desuperheat.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh4.cooling.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.condense.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.desuperheat.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh6.cooling.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.condense.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.desuperheat.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh7.cooling.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.condense.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.condense.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.desuperheat.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.desuperheat.area
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.cooling.overall_heat_transfer_coefficient[0.0]
# 2020-09-04 15:08:07 [WARNING] idaes.core.util.scaling: Accessing missing scaling factor for fs.fwh8.cooling.area
# 2020-09-04 15:08:07 [INFO] idaes.init.Steam Cycle Model: Starting initialization
# 2020-09-04 15:08:07 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_split: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_stage[1]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_stage[2]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_stage[3]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_stage[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:08 [INFO] idaes.init.fs.turb.inlet_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:09 [INFO] idaes.init.fs.turb.hp_split[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:09 [INFO] idaes.init.fs.turb.hp_split[7]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:09 [INFO] idaes.init.fs.turb.ip_split[5]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:10 [INFO] idaes.init.fs.turb.ip_split[10]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:10 [INFO] idaes.init.fs.turb.lp_split[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:10 [INFO] idaes.init.fs.turb.lp_split[8]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.lp_split[10]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.lp_split[11]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.outlet_stage: Initialization Complete (Outlet Stage): optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.inlet_split: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.inlet_stage[1]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.inlet_stage[2]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:11 [INFO] idaes.init.fs.turb.inlet_stage[3]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:12 [INFO] idaes.init.fs.turb.inlet_stage[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:12 [INFO] idaes.init.fs.turb.inlet_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:12 [INFO] idaes.init.fs.turb.hp_split[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:12 [INFO] idaes.init.fs.turb.hp_split[7]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:13 [INFO] idaes.init.fs.turb.ip_split[5]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:13 [INFO] idaes.init.fs.turb.ip_split[10]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:13 [INFO] idaes.init.fs.turb.lp_split[4]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:14 [INFO] idaes.init.fs.turb.lp_split[8]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:14 [INFO] idaes.init.fs.turb.lp_split[10]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:14 [INFO] idaes.init.fs.turb.lp_split[11]: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:14 [INFO] idaes.init.fs.turb.outlet_stage: Initialization Complete (Outlet Stage): optimal - Optimal Solution Found
# 2020-09-04 15:08:16 [INFO] idaes.init.Steam Cycle Model: Full turbine solve complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Ipopt 3.13.2: tol=1e-07
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: linear_solver=ma27
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: max_iter=40
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: ******************************************************************************
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: For more information visit http://projects.coin-or.org/Ipopt
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: This version of Ipopt was compiled from source code available at
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: for large-scale scientific computation.  All technical papers, sales and
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: publicity material resulting from use of the HSL codes within IPOPT must
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: contain the following acknowledgement:
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: HSL, a collection of Fortran codes for large-scale scientific
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: computation. See http://www.hsl.rl.ac.uk.
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: ******************************************************************************
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of nonzeros in equality constraint Jacobian...:        9
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of nonzeros in Lagrangian Hessian.............:        2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Total number of variables............................:        5
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: variables with only lower bounds:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: variables with lower and upper bounds:        2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: variables with only upper bounds:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Total number of equality constraints.................:        5
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Total number of inequality constraints...............:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: inequality constraints with only lower bounds:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: inequality constraints with lower and upper bounds:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: inequality constraints with only upper bounds:        0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: 0  0.0000000e+00 5.46e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: 1  0.0000000e+00 0.00e+00 1.00e-07  -1.0 5.46e+07    -  9.90e-01 1.00e+00h  1
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of Iterations....: 1
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: (scaled)                 (unscaled)
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of objective function evaluations             = 2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of objective gradient evaluations             = 2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of equality constraint evaluations            = 2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of inequality constraint evaluations          = 0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of equality constraint Jacobian evaluations   = 2
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of inequality constraint Jacobian evaluations = 0
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Number of Lagrangian Hessian evaluations             = 1
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Total CPU secs in IPOPT (w/o function evaluations)   =      0.011
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: Total CPU secs in NLP function evaluations           =      0.000
# 2020-09-04 15:08:16 [DEBUG] idaes.solve.fs.bfpt: EXIT: Optimal Solution Found.
# 2020-09-04 15:08:16 [INFO] idaes.init.fs.condenser_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:16 [INFO] idaes.init.Steam Cycle Model: Condenser initialized: optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.hotwell: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1.drain_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1.condense.side_1: Initialization Complete
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1.condense.side_2: Initialization Complete
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1: Condensing shell inlet delta T = 16.329858829425035
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1: Condensing Shell outlet delta T = 30.71648562473314
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1: Steam Flow = 1404.222019573027
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Ipopt 3.13.2: tol=1e-07
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: linear_solver=ma27
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: max_iter=40
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: ******************************************************************************
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: For more information visit http://projects.coin-or.org/Ipopt
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: This version of Ipopt was compiled from source code available at
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: for large-scale scientific computation.  All technical papers, sales and
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: publicity material resulting from use of the HSL codes within IPOPT must
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: contain the following acknowledgement:
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: HSL, a collection of Fortran codes for large-scale scientific
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: computation. See http://www.hsl.rl.ac.uk.
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: ******************************************************************************
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of nonzeros in equality constraint Jacobian...:        9
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of nonzeros in Lagrangian Hessian.............:        2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Total number of variables............................:        5
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: variables with only lower bounds:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: variables with lower and upper bounds:        2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: variables with only upper bounds:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Total number of equality constraints.................:        5
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Total number of inequality constraints...............:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: inequality constraints with only lower bounds:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: inequality constraints with lower and upper bounds:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: inequality constraints with only upper bounds:        0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: 0  0.0000000e+00 5.91e-01 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: 1  0.0000000e+00 1.11e-16 2.24e-07  -1.0 5.91e+06    -  9.90e-01 1.00e+00h  1
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of Iterations....: 1
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: (scaled)                 (unscaled)
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Constraint violation....:   1.1102230246251565e-16    1.1102230246251565e-16
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Overall NLP error.......:   1.1102230246251565e-16    1.1102230246251565e-16
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of objective function evaluations             = 2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of objective gradient evaluations             = 2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of equality constraint evaluations            = 2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of inequality constraint evaluations          = 0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of equality constraint Jacobian evaluations   = 2
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of inequality constraint Jacobian evaluations = 0
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Number of Lagrangian Hessian evaluations             = 1
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Total CPU secs in IPOPT (w/o function evaluations)   =      0.020
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: Total CPU secs in NLP function evaluations           =      0.000
# 2020-09-04 15:08:17 [DEBUG] idaes.solve.fs.fwh1_pump: EXIT: Optimal Solution Found.
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh1_return: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh2.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:17 [INFO] idaes.init.fs.fwh2.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.drain_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:18 [WARNING] idaes.init.fs.fwh2: The steam sat. temperature (335.22681617422495) is near the feedwater inlet temperature (314.24557686365085)
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.condense.side_1: Initialization Complete
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.condense.side_2: Initialization Complete
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:18 [INFO] idaes.init.fs.fwh2.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh2: Condensing shell inlet delta T = 16.699502745554252
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh2: Condensing Shell outlet delta T = 20.78082416024333
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh2: Steam Flow = 250.3556641023727
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh2: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.drain_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [WARNING] idaes.init.fs.fwh3: The steam sat. temperature (347.7746043121486) is near the feedwater inlet temperature (319.0660781963397)
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.condense.side_1: Initialization Complete
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.condense.side_2: Initialization Complete
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:20 [INFO] idaes.init.fs.fwh3.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:21 [INFO] idaes.init.fs.fwh3.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh3: Condensing shell inlet delta T = 24.63104500123077
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh3: Condensing Shell outlet delta T = 28.495296885859283
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh3: Steam Flow = 241.32219655312633
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh3: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh4.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh4.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh4.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh4.condense.side_1: Initialization Complete
# 2020-09-04 15:08:22 [INFO] idaes.init.fs.fwh4.condense.side_2: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4: Condensing shell inlet delta T = 45.25088461743103
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4: Condensing Shell outlet delta T = 52.34638289753992
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4: Steam Flow = 276.7852920837227
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh4: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh5_da: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.drain_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.condense.side_1: Initialization Complete
# 2020-09-04 15:08:23 [INFO] idaes.init.fs.fwh6.condense.side_2: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6: Condensing shell inlet delta T = 59.78212064758779
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6: Condensing Shell outlet delta T = 87.09589872158445
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6: Steam Flow = 2366.1485680980545
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh6: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.drain_mix: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.condense.side_1: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.condense.side_2: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:24 [INFO] idaes.init.fs.fwh7.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh7.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh7: Condensing shell inlet delta T = 89.30307203814809
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh7: Condensing Shell outlet delta T = 114.38082334925522
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh7: Steam Flow = 3966.8330426963985
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh7: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.desuperheat.side_1: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.desuperheat.side_2: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.desuperheat: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.condense.side_1: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.condense.side_2: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.condense: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.condense: Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.cooling.side_1: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.cooling.side_2: Initialization Complete
# 2020-09-04 15:08:25 [INFO] idaes.init.fs.fwh8.cooling: Initialization Completed, optimal - Optimal Solution Found
# 2020-09-04 15:08:26 [INFO] idaes.init.fs.fwh8: Condensing shell inlet delta T = 120.19470404304448
# 2020-09-04 15:08:26 [INFO] idaes.init.fs.fwh8: Condensing Shell outlet delta T = 125.91663471700679
# 2020-09-04 15:08:26 [INFO] idaes.init.fs.fwh8: Steam Flow = 1753.7611957937443
# 2020-09-04 15:08:26 [INFO] idaes.init.fs.fwh8: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:32 [INFO] idaes.init.Steam Cycle Model: Initialization Complete: optimal - Optimal Solution Found
# Ipopt 3.13.2: tol=1e-07
# linear_solver=ma27
# max_iter=40
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2322
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      815
#
# Total number of variables............................:      860
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:      444
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      860
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.59e-05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.2375806802729130e-08    3.5896897315979004e-05
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.2375806802729130e-08    3.5896897315979004e-05
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.663
# Total CPU secs in NLP function evaluations           =      0.006
#
# EXIT: Optimal Solution Found.
# 0
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 57072.56349970795
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [WARNING] idaes.core.property_meta: DEPRECATED: IDAES is moving to using Pyomo Units when defining default units, which are used to automatically determine units of measurement for quantities and convert where necessary. Users are strongly encouraged to convert their property packages to use Pyomo Units objects.
# 2020-09-04 15:08:34 [INFO] idaes.init.fs.ECON.side_1: Initialization Complete
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Ipopt 3.13.2: tol=1e-06
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: max_iter=100
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: ******************************************************************************
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: For more information visit http://projects.coin-or.org/Ipopt
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This version of Ipopt was compiled from source code available at
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: for large-scale scientific computation.  All technical papers, sales and
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: publicity material resulting from use of the HSL codes within IPOPT must
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: contain the following acknowledgement:
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: HSL, a collection of Fortran codes for large-scale scientific
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: computation. See http://www.hsl.rl.ac.uk.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: ******************************************************************************
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in equality constraint Jacobian...:       39
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in Lagrangian Hessian.............:       57
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total number of variables............................:       15
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with only lower bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with lower and upper bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with only upper bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total number of equality constraints.................:       15
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total number of inequality constraints...............:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: inequality constraints with only lower bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: inequality constraints with lower and upper bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: inequality constraints with only upper bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: 0  0.0000000e+00 2.06e+07 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: 1  0.0000000e+00 4.66e-05 0.00e+00  -1.0 9.66e+02    -  1.00e+00 1.00e+00h  1
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: 2  0.0000000e+00 6.94e-18 0.00e+00  -5.7 4.66e-05    -  1.00e+00 1.00e+00h  1
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of Iterations....: 2
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: (scaled)                 (unscaled)
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Constraint violation....:   4.7371437240658823e-19    6.9388939039072284e-18
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Overall NLP error.......:   4.7371437240658823e-19    6.9388939039072284e-18
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of objective function evaluations             = 3
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of objective gradient evaluations             = 3
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of equality constraint evaluations            = 3
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of inequality constraint evaluations          = 0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of equality constraint Jacobian evaluations   = 3
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of inequality constraint Jacobian evaluations = 0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of Lagrangian Hessian evaluations             = 2
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total CPU secs in NLP function evaluations           =      0.000
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: EXIT: Optimal Solution Found.
# 2020-09-04 15:08:34 [INFO] idaes.init.fs.ECON.side_2.properties_in: Initialization Step 1 optimal - Optimal Solution Found.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Ipopt 3.13.2: tol=1e-06
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: max_iter=100
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: ******************************************************************************
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: For more information visit http://projects.coin-or.org/Ipopt
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This version of Ipopt was compiled from source code available at
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: for large-scale scientific computation.  All technical papers, sales and
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: publicity material resulting from use of the HSL codes within IPOPT must
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: contain the following acknowledgement:
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: HSL, a collection of Fortran codes for large-scale scientific
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: computation. See http://www.hsl.rl.ac.uk.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: ******************************************************************************
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in equality constraint Jacobian...:       40
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Number of nonzeros in Lagrangian Hessian.............:       57
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: Total number of variables............................:       16
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with only lower bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with lower and upper bounds:        0
# 2020-09-04 15:08:34 [DEBUG] idaes.solve.fs.ECON.side_2.properties_in: variables with only upper bounds:        0
# ...
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 7  0.0000000e+00 1.36e+10 5.22e+03  -1.0 1.51e+06    -  9.70e-03 5.17e-01h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 8  0.0000000e+00 1.28e+10 8.29e+02  -1.0 7.76e+05    -  6.08e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 9  0.0000000e+00 2.18e+07 4.75e+01  -1.0 2.99e+05    -  9.90e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 10  0.0000000e+00 4.23e+04 1.83e-01  -1.0 1.48e+01    -  9.90e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 11  0.0000000e+00 1.62e-01 1.72e-06  -1.0 2.88e-02    -  9.90e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: 12  0.0000000e+00 2.72e-07 1.90e-09  -1.0 1.10e-07    -  9.95e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of Iterations....: 12
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: (scaled)                 (unscaled)
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Constraint violation....:   1.0793449528650088e-10    2.7194619178771973e-07
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Overall NLP error.......:   1.0793449528650088e-10    2.7194619178771973e-07
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of objective function evaluations             = 13
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of objective gradient evaluations             = 13
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of equality constraint evaluations            = 13
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of inequality constraint evaluations          = 0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of equality constraint Jacobian evaluations   = 13
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of inequality constraint Jacobian evaluations = 0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Number of Lagrangian Hessian evaluations             = 12
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Total CPU secs in IPOPT (w/o function evaluations)   =      0.005
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: Total CPU secs in NLP function evaluations           =      0.000
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1: EXIT: Optimal Solution Found.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.mix1
# 2020-09-04 15:08:38 [INFO] idaes.init.fs.mix1: Initialization Complete: optimal - Optimal Solution Found
# 2020-09-04 15:08:38 [INFO] idaes.init.fs.mix1.Reheat_out_state: fs.mix1.Reheat_out_state State Released.
# 2020-09-04 15:08:38 [INFO] idaes.init.fs.mix1.PrSH_out_state: fs.mix1.PrSH_out_state State Released.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Ipopt 3.13.2:
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: ******************************************************************************
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: For more information visit http://projects.coin-or.org/Ipopt
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: This version of Ipopt was compiled from source code available at
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: for large-scale scientific computation.  All technical papers, sales and
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: publicity material resulting from use of the HSL codes within IPOPT must
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: contain the following acknowledgement:
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: HSL, a collection of Fortran codes for large-scale scientific
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: computation. See http://www.hsl.rl.ac.uk.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: ******************************************************************************
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: This is Ipopt version 3.13.2, running with linear solver ma27.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of nonzeros in equality constraint Jacobian...:        8
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of nonzeros in Lagrangian Hessian.............:        2
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Total number of variables............................:        5
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: variables with only lower bounds:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: variables with lower and upper bounds:        2
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: variables with only upper bounds:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Total number of equality constraints.................:        5
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Total number of inequality constraints...............:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: inequality constraints with only lower bounds:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: inequality constraints with lower and upper bounds:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: inequality constraints with only upper bounds:        0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: 0  0.0000000e+00 4.84e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: 1  0.0000000e+00 2.38e-07 6.74e-01  -1.0 2.49e+07    -  6.76e-01 1.00e+00h  1
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: 2  0.0000000e+00 0.00e+00 5.51e-03  -1.0 2.24e-08    -  9.90e-01 1.00e+00   0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of Iterations....: 2
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: (scaled)                 (unscaled)
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of objective function evaluations             = 3
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of objective gradient evaluations             = 3
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of equality constraint evaluations            = 3
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of inequality constraint evaluations          = 0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of equality constraint Jacobian evaluations   = 3
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of inequality constraint Jacobian evaluations = 0
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Number of Lagrangian Hessian evaluations             = 2
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Total CPU secs in IPOPT (w/o function evaluations)   =      0.002
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: Total CPU secs in NLP function evaluations           =      0.000
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1: EXIT: Optimal Solution Found.
# 2020-09-04 15:08:38 [DEBUG] idaes.solve.fs.ATMP1
# 2020-09-04 15:08:38 [INFO] idaes.init.fs.ATMP1: Initialization Complete: optimal - Optimal Solution Found
# initialization done
# solving square problem disconnected
# Ipopt 3.13.2: tol=1e-07
# linear_solver=ma27
# max_iter=40
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     2963
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1250
#
# Total number of variables............................:     1127
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:      514
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1127
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.23e-05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 0
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.2375806802729130e-08    6.2333419919013977e-05
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.2375806802729130e-08    6.2333419919013977e-05
#
#
# Number of objective function evaluations             = 1
# Number of objective gradient evaluations             = 1
# Number of equality constraint evaluations            = 1
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.703
# Total CPU secs in NLP function evaluations           =      0.007
#
# EXIT: Optimal Solution Found.
# unfix inlet conditions, degreeso of freedom = 63
# connecting flowsheets, degrees of freedom = 0
# solving full plant model
# Ipopt 3.13.2: tol=1e-06
# linear_solver=ma27
# max_iter=40
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3560
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1848
#
# Total number of variables............................:     1197
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1197
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.60e+06 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.60e+07 0.00e+00  -1.0 7.41e+07    -  1.00e+00 1.00e+00h  1
#    2  0.0000000e+00 1.22e+06 0.00e+00  -1.0 6.28e+06    -  1.00e+00 1.00e+00h  1
#    3  0.0000000e+00 6.97e+03 0.00e+00  -1.0 3.60e+05    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 3.17e-01 0.00e+00  -2.5 4.71e+03    -  1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 1.34e-06 0.00e+00  -5.7 1.41e+01    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   6.8821748300251784e-09    1.3411045074462891e-06
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   6.8821748300251784e-09    1.3411045074462891e-06
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.741
# Total CPU secs in NLP function evaluations           =      3.490
#
# EXIT: Optimal Solution Found.

# %% [markdown]
# ## 5. Creating a PFD with results and a stream table
#
# The steam cycle results can be displayed on the PFD and as a stream table, by running the following cells.

# %%
import pkg_resources
import pyomo.environ as pyo
from idaes.power_generation.flowsheets.supercritical_steam_cycle import (
    create_stream_table_dataframe,
    pfd_result,
)
# Create stream results as Pandas dataframe 
df = create_stream_table_dataframe(streams=m._streams, orient="index")
# Create a new PFD with simulation results
init_pfd = pkg_resources.resource_string(
    "idaes.power_generation.flowsheets.supercritical_steam_cycle",
    "supercritical_steam_cycle.svg"
)
res_pfd = pfd_result(m, df, svg=init_pfd)
# Display PFD with results.
display(SVG(res_pfd))

# %%
# Display the stream table.
df
# Out:
#                             Molar Flow (mol/s)  Mass Flow (kg/s)       T (K)  \
# COND_01                           1.734248e+04        312.429714  298.536846
# COND_02                           1.734248e+04        312.429696  298.536846
# COND_03                           1.734248e+04        312.429696  298.615580
# CW01                              2.500000e+06      45038.200000  295.536846
# CW02                              2.500000e+06      45038.200000  299.443130
# EXHST_BFPT                        1.549878e+03         27.921478  299.048619
# EXHST_MAIN                        1.579261e+04        284.508237  299.048619
# EXTR_BFPT_A                       1.549878e+03         27.921478  542.370671
# EXTR_HP4                          1.870175e+03         33.691732  697.660214
# EXTR_HP7                          1.294639e+03         23.323279  604.066553
# EXTR_IP10                         8.656748e+02         15.595373  542.370671
# EXTR_IP5                          8.154389e+02         14.690360  700.503066
# EXTR_LP10                         1.560014e+02          2.810408  334.954227
# EXTR_LP11                         4.484037e+02          8.078118  329.070787
# EXTR_LP4                          2.786723e+02          5.020360  429.319628
# EXTR_LP8                          1.459804e+02          2.629877  347.478068
# FW01A                             1.734248e+04        312.429696  312.572229
# FW01B                             1.837154e+04        330.968459  313.505913
# FW02                              1.837154e+04        330.968459  318.453744
# FW03                              1.837154e+04        330.968459  323.112736
# FW04                              1.837154e+04        330.968459  332.072238
# FW05A                             2.321747e+04        418.269204  376.966294
# FW05B                             2.321747e+04        418.269204  380.166382
# FW06                              2.321747e+04        418.269204  411.866853
# FW07                              2.321747e+04        418.269204  441.257693
# FW08                              2.321747e+04        418.269204  477.658459
# FWH1_DRN1                         1.029058e+03         18.538763  329.070787
# FWH1_DRN2                         1.029058e+03         18.538763  329.191244
# FWH2_DRN                          5.806540e+02         10.460645  326.378658
# FWH3_DRN                          4.246527e+02          7.650237  336.670079
# FWH4_DRN                          2.786723e+02          5.020360  349.219294
# FWH6_DRN                          3.980253e+03         71.705372  449.423874
# FWH7_DRN                          3.164814e+03         57.015012  517.395258
# FWH8_DRN                          1.870175e+03         33.691732  553.641009
# MAKEUP_01                        -1.000000e-03         -0.000018  306.248063
# RHT_COLD                          2.005266e+04        361.254211  604.066553
# RHT_HOT                           2.005266e+04        361.254211  894.210580
# STEAM_LP                          1.682166e+04        303.046999  542.370671
# STEAM_MAIN                        2.321747e+04        418.269222  866.481104
# THRTL1                            5.804367e+03        104.567306  862.986828
# THRTL2                            5.804367e+03        104.567306  862.986828
# THRTL3                            5.804367e+03        104.567306  862.986828
# THRTL4                            5.804367e+03        104.567306  862.986828
# condenser_mix_to_condenser        1.734248e+04        312.429714  299.048619
#
#                                   P (Pa)  Vapor Fraction  \
# COND_01                     3.343617e+03        0.000000
# COND_02                     3.343617e+03        0.000000
# COND_03                     1.003344e+06        0.000000
# CW01                        5.000000e+05        0.000000
# CW02                        5.000000e+05        0.000000
# EXHST_BFPT                  3.343617e+03        0.995449
# EXHST_MAIN                  3.343617e+03        0.961002
# EXTR_BFPT_A                 3.371147e+05        1.000000
# EXTR_HP4                    8.610047e+06        1.000000
# EXTR_HP7                    4.408344e+06        1.000000
# EXTR_IP10                   3.371147e+05        1.000000
# EXTR_IP5                    1.167629e+06        1.000000
# EXTR_LP10                   2.167273e+04        0.969336
# EXTR_LP11                   1.647128e+04        0.958543
# EXTR_LP4                    1.124688e+05        1.000000
# EXTR_LP8                    3.752204e+04        0.992263
# FW01A                       1.003344e+06        0.000000
# FW01B                       1.003344e+06        0.000000
# FW02                        1.003344e+06        0.000000
# FW03                        1.003344e+06        0.000000
# FW04                        1.003344e+06        0.000000
# FW05A                       1.003344e+06        0.000000
# FW05B                       2.506075e+07        0.000000
# FW06                        2.506075e+07        0.000000
# FW07                        2.506075e+07        0.000000
# FW08                        2.506075e+07        0.000000
# FWH1_DRN1                   1.647128e+04        0.000000
# FWH1_DRN2                   1.216471e+06        0.000000
# FWH2_DRN                    2.167273e+04        0.000000
# FWH3_DRN                    3.752204e+04        0.000000
# FWH4_DRN                    1.124688e+05        0.000000
# FWH6_DRN                    1.167629e+06        0.000000
# FWH7_DRN                    4.408344e+06        0.000000
# FWH8_DRN                    8.610047e+06        0.000000
# MAKEUP_01                   1.013250e+05        0.000000
# RHT_COLD                    4.408344e+06        1.000000
# RHT_HOT                     4.044192e+06        1.000000
# STEAM_LP                    3.371147e+05        1.000000
# STEAM_MAIN                  2.423000e+07        0.000000
# THRTL1                      2.314612e+07        0.000000
# THRTL2                      2.314612e+07        0.000000
# THRTL3                      2.314612e+07        0.000000
# THRTL4                      2.314612e+07        0.000000
# condenser_mix_to_condenser  3.343617e+03        0.964080
#
#                             Molar Enthalpy (J/mol) Vap  \
# COND_01                                   4.588768e+04
# COND_02                                   4.588768e+04
# COND_03                                  -2.610215e+06
# CW01                                      3.633362e+04
# CW02                                      4.081315e+04
# EXHST_BFPT                                4.590532e+04
# EXHST_MAIN                                4.590532e+04
# EXTR_BFPT_A                               5.415070e+04
# EXTR_HP4                                  5.757168e+04
# EXTR_HP7                                  5.465551e+04
# EXTR_IP10                                 5.415070e+04
# EXTR_IP5                                  5.981860e+04
# EXTR_LP10                                 4.705540e+04
# EXTR_LP11                                 4.687051e+04
# EXTR_LP4                                  5.022619e+04
# EXTR_LP8                                  4.744261e+04
# FW01A                                    -4.541851e+12
# FW01B                                     4.563896e+04
# FW02                                     -3.150814e+06
# FW03                                      4.639083e+04
# FW04                                      3.732768e+04
# FW05A                                    -7.787225e+04
# FW05B                                     4.856079e+04
# FW06                                      4.967459e+04
# FW07                                      5.070528e+04
# FW08                                      5.198617e+04
# FWH1_DRN1                                 4.687051e+04
# FWH1_DRN2                                 4.668537e+04
# FWH2_DRN                                  4.674796e+04
# FWH3_DRN                                  4.704830e+04
# FWH4_DRN                                  4.717411e+04
# FWH6_DRN                                  4.956449e+04
# FWH7_DRN                                  4.937865e+04
# FWH8_DRN                                  4.485564e+04
# MAKEUP_01                                 4.427422e+04
# RHT_COLD                                  5.465551e+04
# RHT_HOT                                   6.707021e+04
# STEAM_LP                                  5.415070e+04
# STEAM_MAIN                                6.271001e+04
# THRTL1                                    6.271001e+04
# THRTL2                                    6.271001e+04
# THRTL3                                    6.271001e+04
# THRTL4                                    6.271001e+04
# condenser_mix_to_condenser                4.590532e+04
#
#                             Molar Enthalpy (J/mol) Liq
# COND_01                                    1917.672297
# COND_02                                    1917.672264
# COND_03                                    1940.256264
# CW01                                       1700.000000
# CW02                                       1994.191013
# EXHST_BFPT                                 1956.223125
# EXHST_MAIN                                 1956.223125
# EXTR_BFPT_A                               21317.755519
# EXTR_HP4                                 129527.766238
# EXTR_HP7                                -582751.349939
# EXTR_IP10                                 21317.755519
# EXTR_IP5                                 129879.597807
# EXTR_LP10                                  4661.155570
# EXTR_LP11                                  4217.535742
# EXTR_LP4                                  11864.652387
# EXTR_LP8                                   5606.563711
# FW01A                                      2990.572509
# FW01B                                      3060.835230
# FW02                                       3433.213320
# FW03                                       3783.938636
# FW04                                       4458.748288
# FW05A                                      7853.449834
# FW05B                                      8417.218989
# FW06                                      10809.854098
# FW07                                      13056.440898
# FW08                                      15896.950318
# FWH1_DRN1                                  4217.535742
# FWH1_DRN2                                  4244.957434
# FWH2_DRN                                   4014.742629
# FWH3_DRN                                   4790.799588
# FWH4_DRN                                   5739.193827
# FWH6_DRN                                  13452.978898
# FWH7_DRN                                  19059.184152
# FWH8_DRN                                  22307.907780
# MAKEUP_01                                  2500.000000
# RHT_COLD                                -582751.349939
# RHT_HOT                                   67070.213740
# STEAM_LP                                  21317.755519
# STEAM_MAIN                                62710.010000
# THRTL1                                    62710.010000
# THRTL2                                    62710.010000
# THRTL3                                    62710.010000
# THRTL4                                    62710.010000
# condenser_mix_to_condenser                 1956.223126
