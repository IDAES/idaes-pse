# %% [markdown]
# # Supercritical Power Plant Flowsheet Example
#
#
# ## 1. Introduction
#
#
# This example is to demonstrate a supercritical pulverized coal power plant model. The power plant consists of two major sub-systems (or flowsheets), a boiler heat exchanger network and a steam cycle. This jupyter notebook provides the workflow to import the steam cycle flowsheet, import the boiler heat exchanger network, connect and run both the flowsheets, and display the main results.

# %% [markdown]
# ## 2. Model Description
#
# The case study demonstrated here is for a ~620MW gross power output. The process flow diagram is shown in section 3 of this jupyter notebook. Figure 1 shows the boiler heat exchanger network, while, figure 2 shows the steam cycle system.
#
# The streams connecting both the flowsheets are:
# &emsp; a) The main steam: that connects the boiler attemperator to the throttle valves of the high pressure turbine
# &emsp; b) The cold reheat: that connects the final stage of the high pressure turbine to the boiler reheater
# &emsp; c) The hot reheat: that connects the boiler reheater to the intermediate pressure turbine
# &emsp; d) The main feed water: that connects the last feed water heater to the boiler economizer
#
# To get a more detailed description of the power plant flowsheet, review the ```SCPC_full_plant.py``` file. For details in terms of specific power plant units (for example dimensions, parameters, and variables), more information can be found at ```supercritical_steam_cycle.py``` and ```boiler_subflowsheet.py```.

# %% [markdown]
# ## 3. Process Flow Diagram (PFD)

# %%
from IPython.display import SVG, display
display('Boiler subsystem PFD',
        SVG(filename='Boiler_scpc_PFD.svg'),
        'Steam Cycle subsystem PFD',
        SVG(filename='../supercritical_steam_cycle/supercritical_steam_cycle.svg'))
# Out:
# 'Boiler subsystem PFD'
# 'Steam Cycle subsystem PFD'

# %% [markdown]
# ## 4. Run power plant model example
#
# This example runs the main ``SCPC_full_plant.py`` script, which, imports two flowsheets (steam cycle and boiler heat exchanger network), builds arcs to connect both flowsheets, and run the full power plant model.

# %%
# import SCPC power plant
# initialize steam cycle, initialize boiler heat exchanger network, connect both flowsheets, 
# and run SCPC plant.
# %run SCPC_full_plant.py
# Out:
# 2020-02-27 16:29:34 - INFO - idaes.init.Steam Cycle Model - Starting initialization
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_split - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.throttle_valve[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.throttle_valve[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.throttle_valve[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.throttle_valve[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:35 - INFO - idaes.init.fs.turb.inlet_stage[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.inlet_stage[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.inlet_stage[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.inlet_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.hp_stages[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.hp_stages[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.hp_stages[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.hp_stages[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:36 - INFO - idaes.init.fs.turb.hp_split[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.hp_stages[5] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.hp_stages[6] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.hp_stages[7] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.hp_split[7] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.ip_stages[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.ip_stages[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.ip_stages[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.ip_stages[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:37 - INFO - idaes.init.fs.turb.ip_stages[5] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_split[5] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_stages[6] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_stages[7] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_stages[8] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_stages[9] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_stages[10] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.ip_split[10] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.lp_stages[1] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:38 - INFO - idaes.init.fs.turb.lp_stages[2] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[3] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_split[4] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[5] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[6] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[7] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[8] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_split[8] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[9] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_stages[10] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:39 - INFO - idaes.init.fs.turb.lp_split[10] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:40 - INFO - idaes.init.fs.turb.lp_stages[11] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:40 - INFO - idaes.init.fs.turb.lp_split[11] - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:40 - INFO - idaes.init.fs.turb.outlet_stage - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:40 - INFO - idaes.init.fs.turb.outlet_stage - Initialization Complete (Outlet Stage): optimal - Optimal Solution Found
# 2020-02-27 16:29:43 - INFO - idaes.init.fs.turb - Flow guess: 21000, Initialized Flow: 15110.253892446182
# 2020-02-27 16:29:43 - INFO - idaes.init.fs.turb - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.bfpt - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.condenser_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.Steam Cycle Model - Condenser initialized: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.hotwell - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.cond_pump - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1.drain_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - WARNING - idaes.init.fs.fwh1 - The steam sat. temperature (324.9939716855387) is near the feedwater inlet temperature (298.61600404216284)
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1 - Condensing shell inlet delta T = 13.533650546381244
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1 - Condensing Shell outlet delta T = 26.377967643376564
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1 - Steam Flow = 1323.211983370246
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:44 - INFO - idaes.init.fs.fwh1_pump - Initialization Step 1 Complete.
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Ipopt 3.12.13: tol=1e-07
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - linear_solver=ma27
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - max_iter=40
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - ******************************************************************************
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - For more information visit http://projects.coin-or.org/Ipopt
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - This version of Ipopt was compiled from source code available at
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - for large-scale scientific computation.  All technical papers, sales and
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - publicity material resulting from use of the HSL codes within IPOPT must
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - contain the following acknowledgement:
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - HSL, a collection of Fortran codes for large-scale scientific
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - computation. See http://www.hsl.rl.ac.uk.
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - ******************************************************************************
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - This is Ipopt version 3.12.13, running with linear solver ma27.
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of nonzeros in equality constraint Jacobian...:       16
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of nonzeros in Lagrangian Hessian.............:        6
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Total number of variables............................:        6
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - variables with only lower bounds:        1
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - variables with lower and upper bounds:        2
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - variables with only upper bounds:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Total number of equality constraints.................:        6
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Total number of inequality constraints...............:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - inequality constraints with only lower bounds:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - inequality constraints with lower and upper bounds:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - inequality constraints with only upper bounds:        0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - 0  0.0000000e+00 1.20e+02 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - 1  0.0000000e+00 1.37e+01 8.77e+01  -1.0 1.20e+06    -  1.10e-02 1.00e+00h  1
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - 2  0.0000000e+00 3.02e-09 9.89e-03  -1.0 1.72e+01    -  9.90e-01 1.00e+00h  1
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of Iterations....: 2
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - (scaled)                 (unscaled)
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Constraint violation....:   3.0195224098861217e-09    3.0195224098861217e-09
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Overall NLP error.......:   3.0195224098861217e-09    3.0195224098861217e-09
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of objective function evaluations             = 3
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of objective gradient evaluations             = 3
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of equality constraint evaluations            = 3
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of inequality constraint evaluations          = 0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of equality constraint Jacobian evaluations   = 3
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of inequality constraint Jacobian evaluations = 0
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Number of Lagrangian Hessian evaluations             = 2
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Total CPU secs in IPOPT (w/o function evaluations)   =      0.013
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - Total CPU secs in NLP function evaluations           =      0.014
# 2020-02-27 16:29:45 - DEBUG - idaes.solve.fs.fwh1_pump - EXIT: Optimal Solution Found.
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh1_pump - Initialization Step 2 optimal - Optimal Solution Found.
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh1_pump - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh1_return - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2.drain_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - WARNING - idaes.init.fs.fwh2 - The steam sat. temperature (330.70971389732415) is near the feedwater inlet temperature (312.4829556965379)
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2 - Condensing shell inlet delta T = 14.327507179139083
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2 - Condensing Shell outlet delta T = 18.051612872239488
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2 - Steam Flow = 226.83426044399206
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh2 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh3.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:45 - INFO - idaes.init.fs.fwh3.drain_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - WARNING - idaes.init.fs.fwh3 - The steam sat. temperature (342.8632065328551) is near the feedwater inlet temperature (316.87022635305925)
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3 - Condensing shell inlet delta T = 22.11260538120356
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3 - Condensing Shell outlet delta T = 25.794317800067024
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3 - Steam Flow = 224.57056189652872
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh3 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh4.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh4.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh4.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:46 - INFO - idaes.init.fs.fwh4.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh4 - Condensing shell inlet delta T = 41.92354860519043
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh4 - Condensing Shell outlet delta T = 48.90062762622737
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh4 - Steam Flow = 256.93191895394267
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh4 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh5_da - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.bfp - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6.drain_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6 - Condensing shell inlet delta T = 53.83790044468005
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6 - Condensing Shell outlet delta T = 79.98012927275792
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6 - Steam Flow = 2230.5687737945846
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh6 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:47 - INFO - idaes.init.fs.fwh7.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7.drain_mix - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7 - Condensing shell inlet delta T = 81.20686760421621
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7 - Condensing Shell outlet delta T = 105.37919807063334
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7 - Steam Flow = 3766.2200251854165
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh7 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8.desuperheat - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8.condense - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8.condense - Initialization Complete (w/ extraction calc): optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8.cooling - Initialization Completed, optimal - Optimal Solution Found
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8 - Condensing shell inlet delta T = 98.1962547027715
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8 - Condensing Shell outlet delta T = 116.224037120789
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8 - Steam Flow = 1500.8085032030951
# 2020-02-27 16:29:48 - INFO - idaes.init.fs.fwh8 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:30:19 - INFO - idaes.init.Steam Cycle Model - Initialization Complete: optimal - Optimal Solution Found
# Ipopt 3.12.13: tol=1e-07
# linear_solver=ma27
# max_iter=40
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     3588
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1721
#
# Total number of variables............................:     1012
#                      variables with only lower bounds:      259
#                 variables with lower and upper bounds:      512
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1012
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e-02 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.00e-04 1.00e-02  -1.0 1.00e-02    -  9.90e-01 9.90e-01h  1
#    2  0.0000000e+00 9.90e-07 9.92e-02  -1.0 1.00e-04    -  9.90e-01 9.90e-01h  1
#    3  0.0000000e+00 1.90e-05 7.43e+04  -1.0 4.96e+00    -  9.90e-01 3.12e-02f  6
#    4  0.0000000e+00 4.14e-06 7.36e+02  -1.0 1.55e-01    -  9.90e-01 1.00e+00f  1
#    5  0.0000000e+00 5.88e-06 9.01e-04  -1.0 2.77e+02    -  1.00e+00 2.50e-01f  3
#    6  0.0000000e+00 5.88e-06 4.21e-01  -2.5 6.09e+01    -  1.00e+00 9.54e-07h 21
#    7  0.0000000e+00 1.64e-06 1.65e-05  -3.8 3.57e+03    -  1.00e+00 1.00e+00H  1
#    8  0.0000000e+00 2.03e-06 2.98e-08  -5.7 4.81e+00    -  1.00e+00 1.00e+00h  1
#    9  0.0000000e+00 2.43e-08 1.49e-08  -8.0 3.75e-01    -  1.00e+00 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
#
# Number of Iterations....: 9
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   3.4244896973868367e+03    3.4244896973868367e+03
# Constraint violation....:   2.4314374513778603e-08    2.4314374513778603e-08
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.4314374513778603e-08    3.4244896973868367e+03
#
#
# Number of objective function evaluations             = 43
# Number of objective gradient evaluations             = 10
# Number of equality constraint evaluations            = 43
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 10
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 9
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.424
# Total CPU secs in NLP function evaluations           =     28.202
#
# EXIT: Optimal Solution Found.
# 0
# 57072.56349970795
# 60200.651879780475
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      254
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      541
#
# Total number of variables............................:       73
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       73
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.42e+07 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.62e+00 0.00e+00  -1.0 1.47e+04    -  1.00e+00 1.00e+00h  1
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Warning: Cutting back alpha due to evaluation error
#    2  0.0000000e+00 1.81e+00 0.00e+00  -1.0 3.62e+00    -  1.00e+00 5.00e-01h  2
#    3  0.0000000e+00 1.32e+00 0.00e+00  -1.0 2.16e+00    -  1.00e+00 1.00e+00h  1
#    4  0.0000000e+00 7.15e-01 0.00e+00  -3.8 3.45e+00    -  1.00e+00 1.00e+00h  1
#    5  0.0000000e+00 1.95e-03 0.00e+00  -3.8 7.15e-01    -  1.00e+00 1.00e+00h  1
#    6  0.0000000e+00 1.46e-11 0.00e+00  -3.8 1.95e-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   2.5651483528870626e-13    1.4551915228366852e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.5651483528870626e-13    1.4551915228366852e-11
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_in Initialisation Step 1 Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      255
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      541
#
# Total number of variables............................:       74
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       74
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 2.03e+06 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.46e-11 0.00e+00  -1.0 1.38e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   1.4530845502388391e-14    1.4551915228366852e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.4530845502388391e-14    1.4551915228366852e-11
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_in Initialisation Step 2 Complete.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_in Initialisation Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:        8
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        8
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 5.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 4.44e-16 0.00e+00  -1.0 5.00e+00    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   4.4408920985006262e-16    4.4408920985006262e-16
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   4.4408920985006262e-16    4.4408920985006262e-16
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_out Initialisation Step 1 Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:        9
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:        9
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        9
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 8.00e+02 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 0.00e+00 0.00e+00  -1.0 1.33e+05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   0.0000000000000000e+00    0.0000000000000000e+00
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.001
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_out Initialisation Step 2 Complete.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_out Initialisation Complete.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_out State Released.
# 2020-02-27 16:30:50 - INFO - idaes.power_generation.unit_models.boiler_heat_exchanger - fs.ECON Initialisation Step 1 Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      393
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      627
#
# Total number of variables............................:      113
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:        6
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      113
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.52e+05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.87e+08 2.42e+04  -1.0 6.13e+07    -  4.09e-05 1.00e+00f  1
#    2  0.0000000e+00 6.23e-02 3.01e-03  -1.0 6.15e+07    -  9.90e-01 1.00e+00h  1
#    3  0.0000000e+00 4.67e-10 3.01e-05  -1.0 2.16e+00    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 3
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   1.9191873227450223e-10    4.6748027671128511e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.9191873227450223e-10    4.6748027671128511e-10
#
#
# Number of objective function evaluations             = 4
# Number of objective gradient evaluations             = 4
# Number of equality constraint evaluations            = 4
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 4
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 3
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.002
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.power_generation.unit_models.boiler_heat_exchanger - fs.ECON Initialisation Step 2 Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:      426
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      653
#
# Total number of variables............................:      118
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:       10
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      118
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.40e+05 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# Error in an AMPL evaluation. Run with "halt_on_ampl_error yes" to see details.
# Warning: Cutting back alpha due to evaluation error
#    1  0.0000000e+00 3.20e+05 2.67e+00  -1.0 1.17e+08    -  7.50e-01 5.00e-01h  2
#    2  0.0000000e+00 9.04e+02 2.67e+00  -1.0 5.06e+07    -  8.85e-01 1.00e+00h  1
#    3  0.0000000e+00 8.32e+00 5.07e-01  -1.0 5.67e+06    -  9.59e-01 1.00e+00h  1
#    4  0.0000000e+00 4.24e-01 2.17e-02  -1.0 1.09e+06    -  9.90e-01 1.00e+00h  1
#    5  0.0000000e+00 1.86e-04 1.67e-05  -1.0 2.30e+04    -  9.90e-01 1.00e+00h  1
#    6  0.0000000e+00 2.15e-10 1.00e-06  -1.0 8.83e+00    -  9.91e-01 1.00e+00h  1
# Cannot recompute multipliers for feasibility problem.  Error in eq_mult_calculator
# Number of Iterations....: 6
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   5.8710080373339186e-03    5.8710080373339186e-03
# Constraint violation....:   3.9362972877405730e-11    2.1464074961841106e-10
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.9362972877405730e-11    5.8710080373339186e-03
#
#
# Number of objective function evaluations             = 7
# Number of objective gradient evaluations             = 7
# Number of equality constraint evaluations            = 8
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 7
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 6
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.006
# Total CPU secs in NLP function evaluations           =      0.016
#
# EXIT: Optimal Solution Found.
# 2020-02-27 16:30:50 - INFO - idaes.power_generation.unit_models.boiler_heat_exchanger - fs.ECON Initialisation Step 3 Complete.
# 2020-02-27 16:30:50 - INFO - idaes.unit_model.properties - fs.ECON.side_2.properties_in State Released.
# 2020-02-27 16:30:50 - INFO - idaes.power_generation.unit_models.boiler_heat_exchanger - fs.ECON Initialisation Complete.
# Ipopt 3.12.13: tol=1e-06
# max_iter=100
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# ...
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - for large-scale scientific computation.  All technical papers, sales and
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - publicity material resulting from use of the HSL codes within IPOPT must
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - contain the following acknowledgement:
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - HSL, a collection of Fortran codes for large-scale scientific
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - computation. See http://www.hsl.rl.ac.uk.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - ******************************************************************************
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - This is Ipopt version 3.12.13, running with linear solver ma27.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of nonzeros in equality constraint Jacobian...:      102
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of nonzeros in Lagrangian Hessian.............:       50
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Total number of variables............................:       37
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - variables with only lower bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - variables with lower and upper bounds:        8
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - variables with only upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Total number of equality constraints.................:       37
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Total number of inequality constraints...............:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - inequality constraints with only lower bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - inequality constraints with lower and upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - inequality constraints with only upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 0  0.0000000e+00 1.00e+05 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 1  0.0000000e+00 1.00e+05 1.08e+03  -1.0 1.46e+07    -  6.73e-05 8.54e-04h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 2  0.0000000e+00 9.99e+04 9.96e+03  -1.0 8.98e+06    -  1.49e-05 1.91e-03f  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 3  0.0000000e+00 9.92e+04 2.18e+04  -1.0 2.57e+06    -  6.93e-05 6.91e-03h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 4  0.0000000e+00 9.74e+04 3.31e+04  -1.0 1.03e+06    -  1.77e-04 1.77e-02h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 5  0.0000000e+00 1.11e+05 3.63e+04  -1.0 2.95e+05    -  6.42e-04 6.42e-02h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 6  0.0000000e+00 1.85e+05 3.47e+04  -1.0 1.21e+05    -  1.82e-03 1.61e-01h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 7  0.0000000e+00 8.27e+05 1.74e+04  -1.0 7.65e+04    -  1.29e-02 5.54e-01h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 8  0.0000000e+00 5.14e+05 4.87e+03  -1.0 3.41e+04    -  6.53e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 9  0.0000000e+00 2.14e+04 6.61e+02  -1.0 5.98e+03    -  9.90e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 10  0.0000000e+00 6.07e+01 3.71e+00  -1.0 1.92e+01    -  9.90e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 11  0.0000000e+00 5.00e-04 6.13e-05  -1.0 5.48e-02    -  9.90e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - 12  0.0000000e+00 7.53e-10 1.43e-09  -1.0 4.51e-07    -  9.96e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of Iterations....: 12
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - (scaled)                 (unscaled)
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Constraint violation....:   2.9888752841804473e-10    7.5306161306798458e-10
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Overall NLP error.......:   2.9888752841804473e-10    7.5306161306798458e-10
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of objective function evaluations             = 13
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of objective gradient evaluations             = 13
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of equality constraint evaluations            = 13
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of inequality constraint evaluations          = 0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of equality constraint Jacobian evaluations   = 13
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of inequality constraint Jacobian evaluations = 0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Number of Lagrangian Hessian evaluations             = 12
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - Total CPU secs in NLP function evaluations           =      0.000
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 - EXIT: Optimal Solution Found.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.mix1 -
# 2020-02-27 16:30:52 - INFO - idaes.init.fs.mix1 - Initialization Complete: optimal - Optimal Solution Found
# 2020-02-27 16:30:52 - INFO - idaes.unit_model.properties - fs.mix1.Reheat_out_state State Released.
# 2020-02-27 16:30:52 - INFO - idaes.unit_model.properties - fs.mix1.PrSH_out_state State Released.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Ipopt 3.12.13:
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - ******************************************************************************
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - This program contains Ipopt, a library for large-scale nonlinear optimization.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Ipopt is released as open source code under the Eclipse Public License (EPL).
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - For more information visit http://projects.coin-or.org/Ipopt
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - This version of Ipopt was compiled from source code available at
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - https://github.com/IDAES/Ipopt as part of the Institute for the Design of
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - This version of Ipopt was compiled using HSL, a collection of Fortran codes
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - for large-scale scientific computation.  All technical papers, sales and
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - publicity material resulting from use of the HSL codes within IPOPT must
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - contain the following acknowledgement:
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - HSL, a collection of Fortran codes for large-scale scientific
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - computation. See http://www.hsl.rl.ac.uk.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - ******************************************************************************
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - This is Ipopt version 3.12.13, running with linear solver ma27.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of nonzeros in equality constraint Jacobian...:       11
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of nonzeros in inequality constraint Jacobian.:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of nonzeros in Lagrangian Hessian.............:        7
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Total number of variables............................:        5
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - variables with only lower bounds:        1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - variables with lower and upper bounds:        2
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - variables with only upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Total number of equality constraints.................:        5
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Total number of inequality constraints...............:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - inequality constraints with only lower bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - inequality constraints with lower and upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - inequality constraints with only upper bounds:        0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - 0  0.0000000e+00 2.49e+07 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - 1  0.0000000e+00 2.24e-08 9.98e-01  -1.0 2.49e+07    -  6.76e-01 1.00e+00h  1
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - 2  0.0000000e+00 1.14e-12 5.51e-03  -1.0 2.24e-08    -  9.90e-01 1.00e+00   0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of Iterations....: 2
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - (scaled)                 (unscaled)
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Constraint violation....:   1.1368683772161603e-12    1.1368683772161603e-12
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Overall NLP error.......:   1.1368683772161603e-12    1.1368683772161603e-12
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of objective function evaluations             = 3
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of objective gradient evaluations             = 3
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of equality constraint evaluations            = 3
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of inequality constraint evaluations          = 0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of equality constraint Jacobian evaluations   = 3
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of inequality constraint Jacobian evaluations = 0
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Number of Lagrangian Hessian evaluations             = 2
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Total CPU secs in IPOPT (w/o function evaluations)   =      0.004
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - Total CPU secs in NLP function evaluations           =      0.003
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 - EXIT: Optimal Solution Found.
# 2020-02-27 16:30:52 - DEBUG - idaes.solve.fs.ATMP1 -
# 2020-02-27 16:30:52 - INFO - idaes.init.fs.ATMP1 - Initialization Complete: optimal - Optimal Solution Found
# initialization done
# solving square problem disconnected
# Ipopt 3.12.13: tol=1e-07
# linear_solver=ma27
# max_iter=40
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.12.13, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     5637
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4501
#
# Total number of variables............................:     1591
#                      variables with only lower bounds:      266
#                 variables with lower and upper bounds:      582
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1591
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.00e-02 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 1.00e-04 1.00e-02  -1.0 3.96e-02    -  9.90e-01 9.90e-01h  1
#    2  0.0000000e+00 9.90e-07 9.92e-02  -1.0 2.36e-03    -  9.90e-01 9.90e-01h  1
#    3  0.0000000e+00 3.06e-06 9.90e-04  -1.0 3.61e+01    -  9.90e-01 1.00e+00f  1
#   Signal handler called from  /home/alee/anaconda3/lib/python3.7/subprocess.py _try_wait 1582
#   Waiting...
#   Signaled process 28131 with signal 2
# ERROR: Solver (ipopt) returned non-zero return code (-1)
# ERROR: See the solver log above for diagnostic information.
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# ~/idaes/idaes-dev/idaes/power_generation/flowsheets/supercritical_power_plant/SCPC_full_plant.py in <module>
#     130     # this is a square problem (i.e. degrees of freedom = 0)
#     131     print('solving square problem disconnected')
# --> 132     results = solver.solve(m, tee=True)
#     133
#     134     # at this point we want to connect the units in both flowsheets
#
# ~/pyomo/pyomo/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     598                     logger.error("Solver log:\n" + str(_status.log))
#     599                 raise pyutilib.common.ApplicationError(
# --> 600                     "Solver (%s) did not exit normally" % self.name)
#     601             solve_completion_time = time.time()
#     602             if self._report_timing:
#
# ApplicationError: Solver (ipopt) did not exit normally

# %% [markdown]
# ## 5. Creating a PFD with results and a stream table
#
# The steam cycle results can be displayed on the PFD and as a stream table, by running the following cells.

# %%
import pkg_resources
import pyomo.environ as pyo
from idaes.power_generation.flowsheets.supercritical_steam_cycle import (
    create_stream_table_dataframe,
    pfd_result,
)
# Create stream results as Pandas dataframe 
df = create_stream_table_dataframe(streams=m._streams, orient="index")
# Create a new PFD with simulation results
init_pfd = pkg_resources.resource_string(
    "idaes.power_generation.flowsheets.supercritical_steam_cycle",
    "supercritical_steam_cycle.svg"
)
res_pfd = pfd_result(m, df, svg=init_pfd)
# Display PFD with results.
display(SVG(res_pfd))

# %%
# Display the stream table.
df
# Out:
#                             Molar Flow (mol/s)  Mass Flow (kg/s)       T (K)  \
# COND_01                           1.842756e+04        331.977668  298.536846
# COND_02                           1.842756e+04        331.977668  298.536846
# COND_03                           1.842756e+04        331.977668  298.615518
# CW01                              2.500000e+06      45038.200000  295.536846
# CW02                              2.500000e+06      45038.200000  299.661493
# EXHST_BFPT                        1.876966e+03         33.814072  299.048659
# EXHST_MAIN                        1.655059e+04        298.163596  299.048659
# EXTR_BFPT_A                       1.876966e+03         33.814072  523.409375
# EXTR_HP4                          1.705028e+03         30.716557  671.280739
# EXTR_HP7                          1.253873e+03         22.588874  581.223898
# EXTR_IP10                         9.157057e+02         16.496694  523.409375
# EXTR_IP5                          8.862606e+02         15.966233  677.078652
# EXTR_LP10                         1.545975e+02          2.785118  332.888069
# EXTR_LP11                         4.288654e+02          7.726131  327.086787
# EXTR_LP4                          2.760967e+02          4.973960  413.962760
# EXTR_LP8                          1.461890e+02          2.633636  345.230190
# FW01A                             1.842756e+04        331.977668  311.096000
# FW01B                             1.943331e+04        350.096513  311.932240
# FW02                              1.943331e+04        350.096513  316.533734
# FW03                              1.943331e+04        350.096513  320.908907
# FW04                              1.943331e+04        350.096513  329.238520
# FW05A                             2.419418e+04        435.864873  372.490376
# FW05B                             2.419418e+04        435.864873  375.819190
# FW06                              2.419418e+04        435.864873  406.267381
# FW07                              2.419418e+04        435.864873  433.349572
# FW08                              2.419418e+04        435.864873  465.941863
# FWH1_DRN1                         1.005749e+03         18.118845  327.086787
# FWH1_DRN2                         1.005749e+03         18.118845  327.205549
# FWH2_DRN                          5.768833e+02         10.392714  324.463862
# FWH3_DRN                          4.222858e+02          7.607596  334.492704
# FWH4_DRN                          2.760967e+02          4.973960  346.588112
# FWH6_DRN                          3.845162e+03         69.271665  444.791974
# FWH7_DRN                          2.958901e+03         53.305432  506.136503
# FWH8_DRN                          1.705028e+03         30.716557  539.113369
# MAKEUP_01                         0.000000e+00          0.000000  306.248063
# RHT_COLD                          2.123528e+04        382.559441  581.223898
# RHT_HOT                           2.123528e+04        382.559441  866.000000
# STEAM_LP                          1.755634e+04        316.282441  523.409375
# STEAM_MAIN                        2.419418e+04        435.864873  866.480917
# THRTL1                            6.048544e+03        108.966218  862.675662
# THRTL2                            6.048544e+03        108.966218  862.675662
# THRTL3                            6.048544e+03        108.966218  862.675662
# THRTL4                            6.048544e+03        108.966218  862.675662
# condenser_mix_to_condenser        1.842756e+04        331.977668  299.048659
#
#                                   P (Pa)  Vapor Fraction  \
# COND_01                     3.343773e+03    0.000000e+00
# COND_02                     3.343773e+03    0.000000e+00
# COND_03                     1.003344e+06    0.000000e+00
# CW01                        5.000000e+05    0.000000e+00
# CW02                        5.000000e+05    0.000000e+00
# EXHST_BFPT                  3.343773e+03    9.954493e-01
# EXHST_MAIN                  3.343773e+03    9.537703e-01
# EXTR_BFPT_A                 3.065208e+05    1.000000e+00
# EXTR_HP4                    7.181977e+06    1.000000e+00
# EXTR_HP7                    3.677172e+06    1.000000e+00
# EXTR_IP10                   3.065208e+05    1.000000e+00
# EXTR_IP5                    1.061664e+06    1.000000e+00
# EXTR_LP10                   1.970588e+04    9.610240e-01
# EXTR_LP11                   1.497647e+04    9.504693e-01
# EXTR_LP4                    1.022620e+05    1.000000e+00
# EXTR_LP8                    3.411684e+04    9.834164e-01
# FW01A                       1.003344e+06    0.000000e+00
# FW01B                       1.003344e+06    0.000000e+00
# FW02                        1.003344e+06    0.000000e+00
# FW03                        1.003344e+06    0.000000e+00
# FW04                        1.003344e+06    0.000000e+00
# FW05A                       1.003344e+06    0.000000e+00
# FW05B                       2.692222e+07    0.000000e+00
# FW06                        2.692222e+07    0.000000e+00
# FW07                        2.692222e+07    0.000000e+00
# FW08                        2.692222e+07    0.000000e+00
# FWH1_DRN1                   1.497647e+04    2.407991e-15
# FWH1_DRN2                   1.214976e+06    0.000000e+00
# FWH2_DRN                    1.970588e+04    0.000000e+00
# FWH3_DRN                    3.411684e+04    0.000000e+00
# FWH4_DRN                    1.022620e+05    0.000000e+00
# FWH6_DRN                    1.061664e+06    0.000000e+00
# FWH7_DRN                    3.677172e+06    0.000000e+00
# FWH8_DRN                    7.181977e+06    0.000000e+00
# MAKEUP_01                   1.013250e+05    0.000000e+00
# RHT_COLD                    3.677172e+06    1.000000e+00
# RHT_HOT                     3.677172e+06    1.000000e+00
# STEAM_LP                    3.065208e+05    1.000000e+00
# STEAM_MAIN                  2.423000e+07    0.000000e+00
# THRTL1                      2.305063e+07    0.000000e+00
# THRTL2                      2.305063e+07    0.000000e+00
# THRTL3                      2.305063e+07    0.000000e+00
# THRTL4                      2.305063e+07    0.000000e+00
# condenser_mix_to_condenser  3.343773e+03    9.580155e-01
#
#                             Molar Enthalpy (J/mol) Vap  \
# COND_01                                   4.588768e+04
# COND_02                                   4.588768e+04
# COND_03                                   4.008501e+04
# CW01                                     -7.136548e+05
# CW02                                     -1.985957e+11
# EXHST_BFPT                                4.590532e+04
# EXHST_MAIN                                4.590532e+04
# EXTR_BFPT_A                               5.347246e+04
# EXTR_HP4                                  5.675814e+04
# EXTR_HP7                                  5.394276e+04
# EXTR_IP10                                 5.347246e+04
# EXTR_IP5                                  5.894380e+04
# EXTR_LP10                                 4.699067e+04
# EXTR_LP11                                 4.680778e+04
# EXTR_LP4                                  4.968896e+04
# EXTR_LP8                                  4.737381e+04
# FW01A                                     4.531495e+04
# FW01B                                     4.543776e+04
# FW02                                      4.594348e+04
# FW03                                      4.626256e+04
# FW04                                     -8.957681e+12
# FW05A                                    -1.786436e+06
# FW05B                                     8.116106e+03
# FW06                                      1.040833e+04
# FW07                                      1.246926e+04
# FW08                                      1.499098e+04
# FWH1_DRN1                                 4.680778e+04
# FWH1_DRN2                                -7.252358e+05
# FWH2_DRN                                  4.668932e+04
# FWH3_DRN                                  4.698317e+04
# FWH4_DRN                                  4.711152e+04
# FWH6_DRN                                  4.949201e+04
# FWH7_DRN                                  4.947934e+04
# FWH8_DRN                                  4.556524e+04
# MAKEUP_01                                 2.529090e+04
# RHT_COLD                                  5.394276e+04
# RHT_HOT                                   6.595562e+04
# STEAM_LP                                  5.347246e+04
# STEAM_MAIN                                6.271000e+04
# THRTL1                                    6.271000e+04
# THRTL2                                    6.271000e+04
# THRTL3                                    6.271000e+04
# THRTL4                                    6.271000e+04
# condenser_mix_to_condenser                4.590532e+04
#
#                             Molar Enthalpy (J/mol) Liq
# COND_01                                    1917.672300
# COND_02                                    1917.672300
# COND_03                                    1940.251614
# CW01                                       1700.000000
# CW02                                       2010.633189
# EXHST_BFPT                                 1956.226184
# EXHST_MAIN                                 1956.226184
# EXTR_BFPT_A                               19587.015998
# EXTR_HP4                                  56758.141814
# EXTR_HP7                                  25270.772671
# EXTR_IP10                                 19587.015998
# EXTR_IP5                                  58943.795999
# EXTR_LP10                                  4505.332380
# EXTR_LP11                                  4067.998185
# EXTR_LP4                                  10673.618809
# EXTR_LP8                                   5436.746923
# FW01A                                      2879.484540
# FW01B                                      2942.412194
# FW02                                       3288.702672
# FW03                                       3618.023643
# FW04                                       4245.261293
# FW05A                                      7513.536784
# FW05B                                      8116.105877
# FW06                                      10408.331479
# FW07                                      12469.260492
# FW08                                      14990.976496
# FWH1_DRN1                                  4067.998185
# FWH1_DRN2                                  4095.387212
# FWH2_DRN                                   3870.444350
# FWH3_DRN                                   4626.540150
# FWH4_DRN                                   5540.289443
# FWH6_DRN                                  13086.399278
# FWH7_DRN                                  18093.970078
# FWH8_DRN                                  20975.244226
# MAKEUP_01                                  2500.000000
# RHT_COLD                                  25270.772671
# RHT_HOT                                   65955.619649
# STEAM_LP                                  19587.015998
# STEAM_MAIN                                62710.000000
# THRTL1                                    62710.000000
# THRTL2                                    62710.000000
# THRTL3                                    62710.000000
# THRTL4                                    62710.000000
# condenser_mix_to_condenser                 1956.226185
